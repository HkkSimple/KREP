# %%
import cv2
import matplotlib.pyplot as plt

# %%
dst = cv2.imread('1.jpg')
org = cv2.imread('2.jpg')

# %%
org_cut = org[341:383,899:943,:]

plt.imshow(org_cut)
plt.show()

# %%
dst_cut = dst[341:383, 989:1021, :]
print(dst_cut.shape)
plt.imshow(dst_cut)
plt.show()
# Out:
# (42, 32, 3)

# %%
new_org_cut = cv2.resize(org_cut, (32, 42))
plt.imshow(new_org_cut)
plt.show()

# %%
dst[341:383, 989:1021, :] = new_org_cut

# %%
plt.imshow(dst)
plt.show()
cv2.imwrite('tt.jpg', dst)
# Out:
# True
